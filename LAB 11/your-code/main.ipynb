# %% [markdown]
# # Antes de empezar:
#
#     Lee el archivo README.md
#     Comenta todo lo que puedas y utiliza los recursos (archivo README.md)
#     ¡Feliz aprendizaje!

# %% [markdown]
# En este ejercicio, generaremos números aleatorios a partir de las disribuciones continuas que aprendimos en la lección. Hay dos formas de generar números aleatorios:
#
# 1. Usando la librería numpy
# 1. Usando la librería Scipy
#
# Utiliza cualquiera de las dos librerías o ambas en este ejercicio.

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Distribución Uniforme
#
# Para generar números aleatorios uniformes entre dos valores dados usando scipy, podemos usar el siguiente código o el código que hemos
# discutido en clase:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.67049059 2.28799582 2.29775385 2.80704767 2.42039242 2.44341154
#  2.89833458 2.37707599 2.11620108 2.382568  ]

# %% [markdown]
# **Tarea:**
#
# 1. Basándote en el código anterior, escribe una función que genere números aleatorios uniformemente distribuidos. Hay varios requisitos para tu función:
#     * Debe aceptar 3 parámetros:
#         * `bottom` - el límite inferior de los números generados
#         * `ceiling` - el límite superior de los números generados
#         * `count` - cuántos números generar
#     * Debe devolver una matriz de números aleatorios distribuidos uniformemente
#
# 2. Llama a tu función con 2 conjuntos de parámetros a continuación:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 3. Traza las distribuciones uniformes generadas anteriormente utilizando histogramas, donde el eje x es el valor y el eje y es el recuento. Que el número de intervalos del histograma sea 10.
#
# El resultado debe ser como el siguiente:
#
# ![image.png](attachment:image.png)

# %%
def generate_uniform_random(bottom, ceiling, count):
    return uniform.rvs(loc=bottom, scale=ceiling-bottom, size=count).tolist()

test = generate_uniform_random(2, 3, 10)

# Imprimir el resultado
print(test)
# Out:
# [2.663221811493335, 2.91359601829386, 2.9863842204336133, 2.9755473554979184, 2.1781596545241406, 2.6404347297090602, 2.778988764320572, 2.0219814331902404, 2.4666663594810823, 2.789519905921404]

# %%
case1 = generate_uniform_random(10, 15, 100)
case2 = generate_uniform_random(10, 60, 1000)

print(case1)
print(case2)
# Out:
# [10.18051971246679, 14.753820739415955, 11.873259746841066, 10.066001005849968, 13.009341371709693, 10.5929986728798, 11.02837983555707, 10.20791488715744, 10.025791551120927, 12.031232789497519, 14.263435051639117, 11.798605469992005, 14.910900536320003, 13.641097281554131, 10.397233469667807, 14.793057060140656, 13.87113039060691, 14.01818464910255, 13.358130337164186, 10.904726130674572, 10.965818721786103, 13.555517324139803, 11.084211460665802, 12.666324139776126, 12.040173251783223, 14.097123389430003, 12.249228665050829, 13.510984562862681, 12.720094852587357, 14.111599418794523, 11.896919093379454, 14.162025702546266, 10.185908485276578, 12.729778427526783, 10.10087361243465, 14.43762287192391, 14.40453662483958, 10.375455115647503, 10.898163793868182, 10.920569534373039, 11.738318803639418, 12.630401170933274, 13.850843578507963, 10.688147602979754, 11.859476734178134, 14.335540028467822, 14.6986177450271, 14.228970116348258, 13.294763226876706, 12.425111834465437, 14.924483541267225, 13.382417266613789, 14.671307584286918, 12.16724335101614, 13.750342354975956, 12.348981425489134, 11.746461771985905, 14.067377092485465, 10.303851732356929, 10.466266041257343, 11.444248796038256, 13.42066268291922, 10.983
 34.75084388940601, 58.94427757559428, 43.97749859890492, 27.812496599551924, 33.79514766656766, 36.58234317310299, 49.67436345609931, 15.281598271922, 30.747670792606083, 31.178625071990115, 37.77307928223039, 27.50407750409306, 56.405509017851074, 18.66397378242875, 18.86564567678808, 51.23113932016648, 55.986680733977344, 51.81100272575476, 20.718002319687702, 15.265447328846285, 47.82562062975378, 47.695895704386636, 27.718686908142022, 37.181454624286715, 55.471743741076395, 26.041308696758588, 33.48224078754332, 40.62638003906995, 21.49192929752514, 40.22948173069568, 32.11552476427151, 14.315374596073928, 56.189855407078625, 42.67906801703987, 41.23312397409634, 16.671610948417793, 18.879621667777283, 16.646230104745516, 57.874998911025266, 56.66804034883721, 14.090658348523935, 26.721711762132834, 10.918646086747438, 43.00348642938467, 17.00528458386756, 50.94209148080485, 43.465746395238284, 53.618990642278874, 13.853670634949847, 31.30656624971778, 19.89475419523848, 44.46676203230486, 29.209890678016727, 56.48981393105056, 57.88532590630181, 26.52755654166872, 15.38554442497769, 18.842193206381857, 47.43877941845681, 54.059952164138004, 14.69113197818149, 13.950237930086386, 20.920564290343194, 28.862515525890856, 31.546286576379025, 15.425354435775521, 34.87759086354771, 29.51458374017452, 12.371658327533222, 23.295833050255833, 54.43569745608476, 24.328241372050392, 43.45807432216243, 44.10424349954636, 24.80070415786578, 26.52852172944504, 35 ...

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(8, 4))

# Histograma para data1
ax1.hist(case1, bins=10, color='blue', alpha=0.7)
ax1.set_title('Histograma de Data 1')
ax1.set_xlabel('Valor')
ax1.set_ylabel('Frecuencia')

# Histograma para data2
ax2.hist(case2, bins=10, color='red', alpha=0.7)
ax2.set_title('Histograma de Data 2')
ax2.set_xlabel('Valor')

# Mostrar la gráfica
plt.tight_layout()
plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# En la primera las frecuencias son menores en rango, pero estan balanceadas. En el segundo hay una distribucion de frecuencias con mas picos y valles.

# %% [markdown]
# ## Distribución Normal
#
# 1. De la misma manera en el reto de Distribución Uniforme, escriba una función que genere números aleatorios distribuidos normalmente.
# 1. Genera 1.000 números distribuidos normalmente con media de 10 y desviación típica de 1
# 1. Genera 1.000 números distribuidos normalmente con una media de 10 y una desviación típica de 50
# 2. Representa gráficamente las distribuciones de los datos generados.
#
# Resultado esperado:
#
# ![image.png](attachment:image.png)

# %%
from scipy.stats import norm

# %%
def generate_standard_random(mean, std, count):
    return norm.rvs(loc=mean, scale=std, size=count).tolist()

test = generate_standard_random(10, 1, 1000)

# Imprimir el resultado
print(test)
# Out:
# [10.239901417865076, 10.933718784363723, 9.401272785347702, 8.602932748149332, 11.553950988293723, 10.679373708371752, 9.570967195357351, 9.11233822923472, 12.365198017150167, 7.822831603449744, 9.467265440255355, 8.895439821703661, 10.603871060388958, 8.594808238875524, 10.987653939937026, 10.289553591418661, 10.595692225252112, 11.674481055438589, 9.958341276019103, 9.207790822390399, 10.497817292421319, 10.837756841987702, 9.073238226368822, 10.568459779390064, 9.026390274913233, 9.62656636042939, 10.260360083935609, 11.017872776655642, 8.
, 7.477995217496406, -4.827289031291876, -90.71803895819104, 25.451235761196166, -89.72597356071644, -9.940661123820696, 13.247270744730937, 61.47267547541704, 6.395673206576277, 3.257117020089863, 9.394606349110237, 55.573715654275965, -44.66729298539198, 6.020347516418656, -101.27579216865846, 64.17626267506591, 17.304950330605713, 5.270003839430633, -10.231346823551931, 58.79530097754098, -25.654508641007574, -15.768303259673083, 65.98061744653293, -49.400714414186915, -24.416850787618486, -108.53481296466046, -61.461372056919515, -1.50680054512857, -27.15453763725327, 23.642399731149602, 42.008758586156844, -24.461944759386718, -38.01580604468608, 100.37040417115888, -12.654306988910385, -30.032757373135993, 65.32189330186569, 14.938001837925752, 76.11901867060887, 18.55663161181831, 45.37581176542115, 86.99491294476528, 47.813796318961295, 78.70596534998184, -30.975550263561352, 44.91279195526774, -2.834313440446799, 84.48009316400318, 3.388194349090722, -8.70649791229927, -12.990652065503667, -6.87712108601178, -50.41123204140175, -33.630183549036765, 54.086763269657006, 25.704900979332145, -61.180149425236834, -3.2035245853604515, 60.77916176107501, 131.01864456984654, -57.78319002142179, -13.249004095808328, -23.187539322341777, 3.017542811501352, 18.367031695292766, 54.86085796795818, 146.1626910277989, -15.315492377550964, -85.7403245869753, 76.21801356413094, -36.21366370583909, -5.310042146361754, -56.45565730062289, 51.487050622935186, 124.44239461042334, -4.215893841010324, -8.32715742589804, 29.008890520618348, -22.03598433403841, 56.235740616298436, -29.732399917274172, 48.91755447939364, -62.74977732131583, -1.781536566517186, -25.433987514075888, 31.649488833482526, -8.90570228066463, 25.71194124313012, 4.843279483439854, -0.10470689128501398, 68.19848837093835, -13.87355339795759, -12.01225842141039, -22.421009343 ...

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(8, 4))

# Histograma para data1
ax1.hist(case3, bins=100, color='blue', alpha=0.7)
ax1.set_title('Histograma de Data 1')
ax1.set_xlabel('Valor')
ax1.set_ylabel('Frecuencia')

# Histograma para data2
ax2.hist(case4, bins=100, color='red', alpha=0.7)
ax2.set_title('Histograma de Data 2')
ax2.set_xlabel('Valor')

# Mostrar la gráfica
plt.tight_layout()
plt.show()

# %%
# your code here

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# La segunda tiene numeros negativos, porque la desviacion estandar es mucho mayor que el valor medio. Las dos tienen un shape parecido.

# %% [markdown]
# ## Distribución Normal de Datos Reales
#
# En este reto vamos a echar un vistazo a los datos reales. Utilizaremos el archivo vehicles.csv para este ejercicio

# %%
path = 'vehicles.csv'

# Cargar los datos
df = pd.read_csv(path, delimiter = ",")

df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %% [markdown]
# Primero importa vehicles.csv.
# A continuación, traza los histogramas de las siguientes variables:
#
# 1. Barriles de combustible/año

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Fuel Barrels/Year'], bins=17, kde=False, color='green', edgecolor='black')
plt.title('Distribucion Fuel Barrels/Year')
plt.xlabel('Fuel Barrels / Year')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %% [markdown]
# 2. Emisiones de CO2 Gramos/Milla

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['CO2 Emission Grams/Mile'], bins=17, kde=False, color='green', edgecolor='black')
plt.title('Distribucion CO2 Emission Grams/Mile')
plt.xlabel('CO2 Emission Grams/Mile')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %% [markdown]
# 3. MPG combinado

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Combined MPG'], bins=17, kde=False, color='green', edgecolor='black')
plt.title('Distribucion Combined MPG')
plt.xlabel('CCombined MPG')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %% [markdown]
# ¿Cuál o cuáles de las variables tienen una distribución casi normal? ¿Cómo lo sabes?

# %%
data = df['Fuel Barrels/Year']

skewness = stats.skew(data)
kurtosis = stats.kurtosis(data)
target_skewness = 0
target_kurtosis = 3

print(f"Asimetria: {skewness} Esperada: {target_skewness} \nKurtosis: {kurtosis} Esperada: {target_kurtosis}")
# Out:
# Asimetria: 0.6382445784906976 Esperada: 0
# Kurtosis: 1.467913801930207 Esperada: 3

# %%
data = df['CO2 Emission Grams/Mile']

skewness = stats.skew(data)
kurtosis = stats.kurtosis(data)
target_skewness = 0
target_kurtosis = 3

print(f"Asimetria: {skewness} Esperada: {target_skewness} \nKurtosis: {kurtosis} Esperada: {target_kurtosis}")
# Out:
# Asimetria: 0.7416608937445333 Esperada: 0
# Kurtosis: 1.2632401888522526 Esperada: 3

# %%
data = df['Combined MPG']

skewness = stats.skew(data)
kurtosis = stats.kurtosis(data)
target_skewness = 0
target_kurtosis = 3

print(f"Asimetria: {skewness} Esperada: {target_skewness} \nKurtosis: {kurtosis} Esperada: {target_kurtosis}")
# Out:
# Asimetria: 1.0677281511016457 Esperada: 0
# Kurtosis: 2.722005828121911 Esperada: 3

# %% [markdown]
# Ninguno de ellos está normalmente ditribuido.

# %% [markdown]
# ## Distribución Exponencial

# %% [markdown]
# 1. Utilizando `numpy.random.exponential`, crea una función que devuelva una lista de números distribuidos exponencialmente con la media de 10.
#
# 1. Utiliza la función para generar dos secuencias de números de tamaño 10 y 100.
#
# 1. 2. Traza las distribuciones como histogramas con el número de bins como 100.
#
# El resultado debe ser como el siguiente:
#
# ![image.png](attachment:image.png)

# %%
def generate_exponential_random(scale, count):
    return np.random.exponential(scale, count).tolist()

case5 = generate_exponential_random(1, 100)
case6 = generate_exponential_random(10, 100)

fig, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(8, 4))

# Histograma para data1
ax1.hist(case6, bins=100, color='blue', alpha=0.7)
ax1.set_title('Histograma de Data 6')
ax1.set_xlabel('Valor')
ax1.set_ylabel('Frecuencia')

# Histograma para data2
ax2.hist(case5, bins=100, color='red', alpha=0.7)
ax2.set_title('Histograma de Data 5')
ax2.set_xlabel('Valor')

# Mostrar la gráfica
plt.tight_layout()
plt.show()

# %% [markdown]
# ¿En qué se diferencian ambas distribuciones?

# %% [markdown]
# La media cambia, por lo que la distribución también cambia.

# %% [markdown]
# ## Distribución Exponencial de datos reales
#
# Supongamos que el tiempo que uno pasa en un banco se distribuye exponencialmente con media de 10 minutos (es decir, λ = 1/10). ¿Cuál es la probabilidad de que un cliente pase menos de quince minutos en el banco?
#
# Escribe un código en python para resolver este problema

# %%
# Definir la distribución exponencial con el parámetro de la tasa. 

expon_dist = stats.expon(scale=10)

# Calcular la probabilidad P(X < 15). # Usamos la función de distribución acumulativa (CDF) de la distribución exponencial.
probabilidad = expon_dist.cdf(15)

# %% [markdown]
# ¿Cuál es la probabilidad de que el cliente pase más de 15 minutos?

# %%
print(f"La probabilidad de que un cliente pase menos de quince minutos en el banco es: {probabilidad:.4f}")
# Out:
# La probabilidad de que un cliente pase menos de quince minutos en el banco es: 0.7769
